# %%
import os
import sklearn
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import enchant
from sklearn.neighbors import NearestNeighbors
import re
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
initial_categories = ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware',
                      'comp.sys.mac.hardware', 'comp.windows.x', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball',
                      'rec.sport.hockey', 'sci.electronics', 'soc.religion.christian', 'talk.politics.mideast',
                      'talk.politics.misc', 'talk.religion.misc']
eng_dict = enchant.Dict('en_US')

# %%
ng_train = fetch_20newsgroups(subset='train', categories=initial_categories, remove=('headers', 'footers', 'quotes'))
print ng_train.keys()
# Out:
# ['description', 'DESCR', 'filenames', 'target_names', 'data', 'target']

# %%
data_train = []

for el in ng_train.data:
    filtered = re.findall(u'(?u)\\b\\w\\w+\\b', el)
    filtered = [filt for filt in filtered if eng_dict.check(filt)]
    data_train.append(' '.join(filtered).lower())
    
print len(data_train)
# Out:
# 8401

# %%
vectorizer = TfidfVectorizer(stop_words='english', strip_accents='ascii')
tfidf_train = vectorizer.fit_transform(data_train)

print tfidf_train.shape
# Out:
# (8401, 31911)

# %%
tfidf_train
# Out:
# <8401x31911 sparse matrix of type '<type 'numpy.float64'>'
# 	with 446838 stored elements in Compressed Sparse Row format>

# %%
valid_inds = []

for i_el, el in enumerate(tfidf_train):
    if el.getnnz() > 0:
        valid_inds.append(i_el)
        
valid_inds = np.asarray(valid_inds)
print len(valid_inds)
        
tfidf_train_filt = tfidf_train[valid_inds]
print tfidf_train_filt.shape
# Out:
# 8144
# (8144, 31911)

# %% [raw]
# np.save('tf-idf_train', tfidf_train_filt)

# %%
predictor = NearestNeighbors(n_neighbors=1, algorithm='brute', metric='cosine').fit(tfidf_train_filt)

# %% [markdown]
# ---

# %%
request = 'something about computers electronic components hardware etc'

# %%
tfidf_test = vectorizer.transform([vectorizer.decode(request)])

print tfidf_test.shape
# Out:
# (1, 31911)

# %%
tfidf_test
# Out:
# <1x31911 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %%
vectorizer.vocabulary_
# Out:
# {u'raining': 23587,
#  u'belligerence': 5624,
#  u'hordes': 15379,
#  u'progressively': 22976,
#  u'foul': 13476,
#  u'wailing': 31020,
#  u'circuitry': 7555,
#  u'spiders': 27224,
#  u'11544': 475,
#  u'hanging': 14749,
#  u'woody': 31586,
#  u'11548': 476,
#  u'cyprus': 9459,
#  u'aggression': 3863,
#  u'spidery': 27225,
#  u'disobeying': 10690,
#  u'canes': 6854,
#  u'7466': 2686,
#  u'quadruple': 23390,
#  u'929392': 3131,
#  u'crossbar': 9229,
#  u'hermann': 15075,
#  u'immature': 15774,
#  u'sinking': 26554,
#  u'roadrunners': 25053,
#  u'rational': 23688,
#  u'965': 3255,
#  u'hough': 15441,
#  u'rashly': 23670,
#  u'pages': 21265,
#  u'oceans': 20626,
#  u'retailers': 24740,
#  u'eugenics': 12155,
#  u'cfc': 7215,
#  u'appropriation': 4555,
#  u'uncongenial': 29932,
#  u'rawhide': 23719,
#  u'classifications': 7653,
#  u'74017': 2670,
#  u'fractal': 13499,
#  u'showroom': 26364,
#  u'961': 3249,
#  u'disturb': 10835,
#  u'recollections': 23906,
#  u'uttering': 30526,
#  u'grueling': 14514,
#  u'wooden': 31579,
#  u'wednesday': 31226,
#  u'happenings': 14766,
#  u'solid': 26977,
#  u'persisted': 21806,
#  u'woods': 31581,
#  u'crotch': 9239,
#  u'amplifications': 4209,
#  u'stereotypical': 27623,
#  u'commented': 8065,
#  u'pantheistic': 21337,
#  u'hanan': 14705,
#  u'puissant': 23247,
#  u'sturm': 27914,
#  u'thrace': 28953,
#  u'gaskets': 13852,
#  u'25286': 1391,
#  u'968': 3261,
#  u'preface': 22654,
#  u'scraper': 25747,
#  u'969': 3262,
#  u'feasibility': 12808,
#  u'miniatures': 19303,
#  u'272': 1452,
#  u'273': 1454,
#  u'274': 1458,
#  u'275': 1461,
#  u'276': 1465,
#  u'sustaining': 28288,
#  u'278': 1471,
#  u'279': 1474,
#  u'sailed': 25422,
#  u'kodak': 17440,
#  u'loathing': 18140,
#  u'seth': 26080,
#  u'inanimate': 15941,
#  u'errors': 12046,
#  u'dialogs': 10318,
#  u'minimize': 19309,
#  u'thunder': 29008,
#  u'cooking': 8790,
#  u'schism': 25664,
#  u'mennonites': 19039,
#  u'100014': 288,
#  u'trainer': 29348,
#  u'usenet': 30486,
#  u'fossil': 13469,
#  u'designing': 10147,
#  u'televangelists': 28685,
#  u'payoff': 21603,
#  u'hallucinating': 14671,
#  u'succumb': 28053,
#  u'inducement': 16113,
#  u'shocks': 26291,
#  u'cull': 9327,
#  u'widget': 31395,
#  u'crouch': 9240,
#  u'chins': 7451,
#  u'mailings': 18485,
#  u'668966': 2473,
#  u'brainwashed': 6263,
#  u'affiliates': 3807,
#  u'atoms': 4937,
#  u'47': 1993,
#  u'greats': 14395,
#  u'china': 7447,
#  u'imnsho': 15809,
#  u'cult': 9338,
#  u'affiliated': 3806,
#  u'virtuoso': 30865,
#  u'chink': 7450,
#  u'natured': 20041,
#  u'quart': 23425,
#  u'cyclical': 9442,
#  u'kids': 17327,
#  u'uplifting': 30423,
#  u'unwillingness': 30390,
#  u'elaborate': 11486,
#  u'climbed': 7728,
#  u'controversy': 8730,
#  u'snowing': 26887,
#  u'1373': 686,
#  u'kinsley': 17373,
#  u'natures': 20042,
#  u'rulebook': 25301,
#  u'spotty': 27323,
#  u'federations': 12827,
#  u'criticism': 9197,
#  u'golden': 14211,
#  u'roadrunner': 25052,
#  u'topography': 29213,
#  u'projection': 22989,
#  u'lengthen': 17818,
#  u'replace': 24457,
#  u'marina': 18683,
#  u'stern': 27628,
#  u'168': 924,
#  u'46862': 1989,
#  u'opponents': 20815,
#  u'derivatives': 10102,
#  u'sternest': 27630,
#  u'dna': 10887,
#  u'browse': 6441,
#  u'abbreviations': 3341,
#  u'3517': 1703,
#  u'cannibal': 6858,
#  u'coordinators': 8817,
#  u'slumping': 26778,
#  u'symphony': 28407,
#  u'music': 19892,
#  u'distortions': 10813,
#  u'strike': 27825,
#  u'dusting': 11265,
#  u'care': 6940,
#  u'sermons': 26056,
#  u'benedikt': 5654,
#  u'vestige': 30740,
#  u'paperwork': 21355,
#  u'standardized': 27473,
#  u'populations': 22410,
#  u'demoted': 9984,
#  u'gravediggers': 14378,
#  u'sputter': 27366,
#  u'reversible': 24834,
#  u'harmless': 14808,
#  u'unpack': 30243,
#  u'circumstances': 7570,
#  u'intake': 16479,
#  u'morally': 19659,
#  u'locked': 18165,
#  u'quartic': 23433,
#  u'40': 1817,
#  u'pursue': 23340,
#  u'selections': 25930,
#  u'plunged': 22263,
#  u'upbringings': 30402,
#  u'advert': 3754,
#  u'locker': 18166,
#  u'interaction': 16522,
#  u'confining': 8412,
#  u'rework': 24895,
#  u'revenues': 24826,
#  u'example': 12253,
#  u'scavenge': 25638,
#  u'grimes': 14448,
#  u'deputy': 10090,
#  u'wang': 31067,
#  u'wand': 31061,
#  u'hyatt': 15590,
#  u'unjust': 30187,
#  u'digit': 10392,
#  u'titanium': 29123,
#  u'caution': 7106,
#  u'want': 31072,
#  u'counseling': 8962,
#  u'68800': 2531,
#  u'cocksucker': 7854,
#  u'absolute': 3405,
#  u'auger': 5024,
#  u'travel': 29474,
#  u'copious': 8827,
#  u'principled': 22838,
#  u'propane': 23059,
#  u'08502': 247,
#  u'playback': 22199,
#  u'saskatchewan': 25522,
#  u'shrug': 26380,
#  u'cadence': 6729,
#  u'fanaticism': 12698,
#  u'1177': 500,
#  u'1176': 499,
#  u'1175': 498,
#  u'1174': 497,
#  u'1173': 496,
#  u'1172': 495,
#  u'1170': 494,
#  u'assimilated': 4854,
#  u'minimized': 19310,
#  u'apocrypha': 4461,
#  u'1178': 502,
#  u'wrong': 31694,
#  u'sentencing': 26008,
#  u'bratislava': 6286,
#  u'unselfish': 30319,
#  u'513': 2093,
#  u'types': 29788,
#  u'opted': 20837,
#  u'entrusted': 11911,
#  u'buzzy': 6688,
#  u'comatose': 7997,
#  u'fictional': 12932,
#  u'sickening': 26414,
#  u'cigarettes': 7541,
#  u'18th': 1029,
#  u'timers': 29087,
#  u'horribly': 15392,
#  u'menlo': 19038,
#  u'torts': 29241,
#  u'carelessness': 6950,
#  u'nonsensical': 20361,
#  u'smashers': 26799,
#  u'1227': 557,
#  u'snugly': 26893,
#  u'622': 2365,
#  u'welcomed': 31262,
#  u'concurrence': 8333,
#  u'1225': 556,
#  u'xi': 31728,
#  u'butcher': 6660,
#  u'backings': 5206,
#  u'stockpiles': 27695,
#  u'rewarded': 24886,
#  u'owens': 21208,
#  u'activating': 3580,
#  u'nurture': 20497,
#  u'626': 2377,
#  u'fir': 13046,
#  u'tailings': 28492,
#  u'fit': 13088,
#  u'221370': 1271,
#  u'unforeseen': 30098,
#  u'screaming': 25762,
#  u'fix': 13098,
#  u'striking': 27830,
#  u'unexplained': 30081,
#  u'survivors': 28269,
#  u'fig': 12960,
#  u'wales': 31036,
#  u'fin': 13001,
#  u'easier': 11333,
#  u'thrones': 28981,
#  u'biding': 5749,
#  u'slate': 26684,
#  u'somerset': 27006,
#  u'scientology': 25697,
#  u'diodes': 10450,
#  u'cpus': 9052,
#  u'photocell': 21940,
#  u'basics': 5431,
#  u'effects': 11438,
#  u'06108': 191,
#  u'velcro': 30662,
#  u'schools': 25683,
#  u'multidimensional': 19829,
#  u'sixteen': 26589,
#  u'slats': 26686,
#  u'eisenhower': 11478,
#  u'saddened': 25394,
#  u'competitiveness': 8163,
#  u'0531': 173,
#  u'magically': 18454,
#  u'thyme': 29022,
#  u'defecate': 9798,
#  u'renditions': 24387,
#  u'barton': 5412,
#  u'disconnection': 10578,
#  u'reimburse': 24201,
#  u'neutron': 20190,
#  u'timeout': 29084,
#  u'volcano': 30932,
#  u'uninfluenced': 30142,
#  u'gumshoe': 14581,
#  u'safely': 25410,
#  u'burial': 6606,
#  u'telescope': 28680,
#  u'series': 26052,
#  u'allah': 4039,
#  u'allan': 4040,
#  u'phoenicians': 21927,
#  u'parasites': 21398,
#  u'393': 1799,
#  u'392': 1798,
#  u'391': 1796,
#  u'390': 1795,
#  u'397': 1809,
#  u'396': 1808,
#  u'395': 1801,
#  u'394': 1800,
#  u'substantially': 28003,
#  u'399': 1813,
#  u'398': 1811,
#  u'message': 19098,
#  u'finishers': 13033,
#  u'rt': 25260,
#  u'ru': 25262,
#  u'rv': 25354,
#  u'drove': 11162,
#  u'rp': 25254,
#  u'rr': 25256,
#  u'rs': 25257,
#  u'108': 392,
#  u'0284': 110,
#  u'mayan': 18863,
#  u'rx': 25356,
#  u'0283': 109,
#  u'gradation': 14298,
#  u'mason': 18767,
#  u'rd': 23736,
#  u'encourage': 11746,
#  u'branch': 6270,
#  u'adapt': 3611,
#  u'mayas': 18864,
#  u'rc': 23733,
#  u'rm': 25044,
#  u'rn': 25046,
#  u'rh': 24907,
#  u'smithfield': 26818,
#  u'misrepresentations': 19416,
#  u'foundation': 13479,
#  u'abbott': 3338,
#  u'stamping': 27464,
#  u'dares': 9542,
#  u'underfoot': 29979,
#  u'threatened': 28962,
#  u'strata': 27776,
#  u'yesterday': 31797,
#  u'attributions': 5000,
#  u'corrects': 8898,
#  u'crowned': 9251,
#  u'estimate': 12113,
#  u'obstructing': 20590,
#  u'universally': 30181,
#  u'chlorine': 7460,
#  u'husbands': 15576,
#  u'enormous': 11851,
#  u'exposing': 12478,
#  u'moment': 19576,
#  u'silicon': 26476,
#  u'ministries': 19320,
#  u'shipped': 26274,
#  u'disturbed': 10838,
#  u'speedy': 27199,
#  u'competed': 8155,
#  u'tempting': 28717,
#  u'1970s': 1118,
#  u'kingdom': 17363,
#  u'symbolize': 28396,
#  u'allocators': 4072,
#  u'renumbered': 24410,
#  u'speeds': 27195,
#  u'purpose': 23332,
#  u'clarita': 7636,
#  u'hearsay': 14942,
#  u'steroids': 27632,
#  u'27799': 1470,
#  u'disfigured': 10630,
#  u'vitro': 30903,
#  u'maladies': 18528,
#  u'visited': 30885,
#  u'procreate': 22913,
#  u'megabytes': 18989,
#  u'60015': 2305,
#  u'langston': 17567,
#  u'clarity': 7637,
#  u'specially': 27152,
#  u'seizures': 25923,
#  u'traction': 29314,
#  u'olds': 20719,
#  u'basketball': 5438,
#  u'service': 26066,
#  u'reuben': 24804,
#  u'unlearning': 30197,
#  u'needed': 20099,
#  u'master': 18787,
#  u'hypothetical': 15622,
#  u'genesis': 13947,
#  u'yip': 31804,
#  u'rewards': 24888,
#  u'rectifier': 23967,
#  u'rectifies': 23968,
#  u'20084': 1168,
#  u'nirvana': 20304,
#  u'rectified': 23966,
#  u'mutilated': 19914,
#  u'defaulted': 9791,
#  u'crawl': 9101,
#  u'positively': 22454,
#  u'270': 1448,
#  u'ahmed': 3898,
#  u'showed': 26356,
#  u'271': 1451,
#  u'07410': 220,
#  u'tree': 29509,
#  u'rusty': 25346,
#  u'idly': 15685,
#  u'blasphemer': 5896,
#  u'regulator': 24184,
#  u'idle': 15683,
#  u'948294': 3206,
#  u'feeling': 12840,
#  u'948290': 3205,
#  u'3750': 1761,
#  u'trev': 29525,
#  u'winnipeg': 31478,
#  u'valiant': 30560,
#  u'willingness': 31432,
#  u'longs': 18216,
#  u'6810': 2517,
#  u'277': 1466,
#  u'spectrum': 27178,
#  u'untrained': 30367,
#  u'antagonistic': 4389,
#  u'consenting': 8519,
#  u'dozed': 11061,
#  u'increment': 16033,
#  u'worlders': 31619,
#  u'constricted': 8589,
#  u'mannheim': 18620,
#  u'dozen': 11062,
#  u'affairs': 3798,
#  u'melvin': 19012,
#  u'wholesome': 31368,
#  u'paramedics': 21383,
#  u'bleachers': 5917,
#  u'rudolph': 25285,
#  u'gripe': 14459,
#  u'vga': 30755,
#  u'sedan': 25888,
#  u'racers': 23517,
#  u'recommended': 23910,
#  u'hyperventilation': 15610,
#  u'instructs': 16451,
#  u'amusing': 4229,
#  u'doors': 10990,
#  u'1229': 558,
#  u'grips': 14462,
#  u'kremlin': 17459,
#  u'shipments': 26273,
#  u'45th': 1968,
#  u'committing': 8090,
#  u'lion': 18053,
#  u'thrilled': 28973,
#  u'diminishing': 10425,
#  u'wells': 31272,
#  u'eliminates': 11563,
#  u'metrics': 19147,
#  u'simplify': 26511,
#  u'mouth': 19757,
#  u'addict': 3625,
#  u'reverence': 24829,
#  u'ashes': 4782,
#  u'relieving': 24299,
#  u'certiorari': 7208,
#  u'expound': 12482,
#  u'dummy': 11228,
#  u'singer': 26540,
#  u'recant': 23855,
#  u'electrified': 11517,
#  u'cams': 6833,
#  u'parametric': 21387,
#  u'purges': 23316,
#  u'tautology': 28602,
#  u'rotary': 25192,
#  u'passes': 21499,
#  u'memberships': 19016,
#  u'tech': 28638,
#  u'women': 31563,
#  u'1763': 959,
#  u'1760': 958,
#  u'mating': 18824,
#  u'scream': 25759,
#  u'came': 6806,
#  u'saying': 25585,
#  u'blatantly': 5906,
#  u'inmates': 16318,
#  u'dickey': 10343,
#  u'insects': 16362,
#  u'meetings': 18982,
#  u'teresa': 28756,
#  u'devised': 10279,
#  u'padded': 21252,
#  u'unaccelerated': 29846,
#  u'participate': 21458,
#  u'lethal': 17855,
#  u'tempted': 28715,
#  u'cheaply': 7349,
#  u'hounded': 15442,
#  u'lessons': 17850,
#  u'orleans': 20941,
#  u'clicked': 7715,
#  u'headline': 14912,
#  u'bonuses': 6100,
#  u'rico': 24938,
#  u'lube': 18322,
#  u'statehouse': 27526,
#  u'bliss': 5950,
#  u'rick': 24934,
#  u'rich': 24921,
#  u'rice': 24920,
#  u'plate': 22179,
#  u'salespeople': 25441,
#  u'remotest': 24366,
#  u'hondo': 15327,
#  u'16199': 885,
#  u'champaign': 7243,
#  u'puckers': 23237,
#  u'outfielders': 21009,
#  u'denounce': 10010,
#  u'terrors': 28798,
#  u'foremost': 13377,
#  u'pocket': 22278,
#  u'3022384': 1549,
#  u'vaccinations': 30541,
#  u'altogether': 4124,
#  u'programming': 22968,
#  u'rugged': 25292,
#  u'societies': 26922,
#  u'contributes': 8714,
#  u'jaguar': 16930,
#  u'spilling': 27238,
#  u'scorched': 25710,
#  u'nicely': 20240,
#  u'blanched': 5884,
#  u'dipping': 10461,
#  u'patch': 21527,
#  u'esteeming': 12109,
#  u'stunningly': 27905,
#  u'adherence': 3652,
#  u'mammon': 18557,
#  u'hasten': 14847,
#  u'boarded': 6019,
#  u'91214': 3089,
#  u'dismissively': 10682,
#  u'pioneering': 22069,
#  u'programmatic': 22964,
#  u'specialist': 27146,
#  u'clarified': 7632,
#  u'sensitivity': 25998,
#  u'recruit': 23958,
#  u'tyndale': 29783,
#  u'radius': 23555,
#  u'resigned': 24620,
#  u'avert': 5107,
#  u'734640769': 2655,
#  u'sedans': 25889,
#  u'advisedly': 3767,
#  u'pressured': 22751,
#  u'lots': 18272,
#  u'irs': 16829,
#  u'rings': 24997,
#  u'propagates': 23055,
#  u'droves': 11163,
#  u'xvi': 31741,
#  u'intentioned': 16516,
#  u'irk': 16793,
#  u'humankind': 15517,
#  u'herb': 15054,
#  u'conductive': 8370,
#  u'ira': 16781,
#  u'offertory': 20671,
#  u'solenoid': 26970,
#  u'skimpy': 26640,
#  u'letting': 17863,
#  u'splinter': 27275,
#  u'petcock': 21859,
#  u'extend': 12499,
#  u'nature': 20040,
#  u'truncheons': 29657,
#  u'optimist': 20844,
#  u'superficial': 28156,
#  u'souvenir': 27081,
#  u'benchmarked': 5647,
#  u'icelandic': 15644,
#  u'unseemly': 30317,
#  u'extent': 12509,
#  u'defiance': 9821,
#  u'pants': 21344,
#  u'debt': 9662,
#  u'tyranny': 29805,
#  u'airflow': 3924,
#  u'veep': 30643,
#  u'psychiatrist': 23203,
#  u'reported': 24482,
#  u'fallacious': 12660,
#  u'6776': 2492,
#  u'sparta': 27126,
#  u'heating': 14964,
#  u'incense': 15962,
#  u'planned': 22162,
#  u'resending': 24590,
#  u'marrying': 18726,
#  u'login': 18192,
#  u'argue': 4647,
#  u'southeastern': 27075,
#  u'jack': 16909,
#  u'eradicate': 11999,
#  u'rehash': 24189,
#  u'poison': 22303,
#  u'fudged': 13667,
#  u'gopher': 14245,
#  u'gypsies': 14616,
#  u'minuses': 19336,
#  u'gleaming': 14104,
#  u'pregnancy': 22669,
#  u'samuelson': 25477,
#  u'godhead': 14193,
#  u'diagnosed': 10301,
#  u'shouting': 26345,
#  u'union': 30158,
#  u'fri': 13601,
#  u'naifs': 19965,
#  u'chiseling': 7459,
#  u'bothers': 6181,
#  u'stadium': 27426,
#  u'privilege': 22867,
#  u'fry': 13658,
#  u'tallest': 28520,
#  u'deportations': 10057,
#  u'toning': 29195,
#  u'dots': 11010,
#  u'conversing': 8751,
#  u'graphical': 14353,
#  u'electrocution': 11521,
#  u'retrospect': 24795,
#  u'spit': 27256,
#  u'9500': 3215,
#  u'onyx': 20773,
#  u'davy': 9595,
#  u'testifies': 28814,
#  u'dave': 9588,
#  u'substance': 27999,
#  u'doubts': 11028,
#  u'worked': 31603,
#  u'haters': 14863,
#  u'spin': 27240,
#  u'expansionists': 12392,
#  u'wildcat': 31410,
#  u'gritty': 14466,
#  u'participatory': 21463,
#  u'easter': 11337,
#  u'professionally': 22941,
#  u'excited': 12290,
#  u'employ': 11681,
#  u'contemplates': 8638,
#  u'preselected': 22717,
#  u'betas': 5708,
#  u'viii': 30816,
#  u'yardarm': 31762,
#  u'2513': 1384,
#  u'077': 225,
#  u'redefinitions': 23998,
#  u'075': 222,
#  u'072': 217,
#  u'070': 207,
#  u'071': 212,
#  u'expending': 12409,
#  u'kohl': 17441,
#  u'conditioned': 8354,
#  u'taunts': 28599,
#  u'elicit': 11554,
#  u'eighteen': 11470,
#  u'upscale': 30440,
#  u'anticipating': 4410,
#  u'womanly': 31560,
#  u'oxymoron': 21223,
#  u'5050': 2076,
#  u'hone': 15328,
#  u'memorial': 19021,
#  u'memoriam': 19022,
#  u'ignored': 15705,
#  u'severity': 26106,
#  u'malefactors': 18535,
#  u'honk': 15338,
#  u'democracies': 9952,
#  u'spews': 27214,
#  u'013846': 62,
#  u'split': 27277,
#  u'elliott': 11577,
#  u'principals': 22835,
#  u'bid': 5748,
#  u'european': 12163,
#  u'voyager': 30979,
#  u'numerics': 20487,
#  u'thereof': 28886,
#  u'effortlessly': 11446,
#  u'equalizing': 11970,
#  u'issac': 16871,
#  u'torpedoes': 29235,
#  u'marched': 18663,
#  u'boiler': 6050,
#  u'supper': 28184,
#  u'0404': 140,
#  u'concluding': 8319,
#  u'lucas': 18327,
#  u'sweeper': 28329,
#  u'askance': 4796,
#  u'1235': 565,
#  u'backhander': 5204,
#  u'academic': 3441,
#  u'academia': 3440,
#  u'vectorized': 30638,
#  u'quantitative': 23409,
#  u'backhanded': 5203,
#  u'corporate': 8881,
#  u'massaging': 18781,
#  u'plaque': 22173,
#  u'outlived': 21034,
#  u'bellow': 5626,
#  u'capitol': 6900,
#  u'absurdities': 3423,
#  u'appropriately': 4551,
#  u'sleepy': 26704,
#  u'hutchinson': 15584,
#  u'birmingham': 5817,
#  u'airbag': 3916,
#  u'rotates': 25195,
#  u'portrayed': 22437,
#  u'amusingly': 4230,
#  u'previous': 22801,
#  u'handshake': 14740,
#  u'hal': 14654,
#  u'ham': 14682,
#  u'han': 14704,
#  u'biodiversity': 5799,
#  u'espouses': 12086,
#  u'advancement': 3737,
#  u'scalable': 25592,
#  u'hag': 14638,
#  u'fortran': 13457,
#  u'mcnamara': 18904,
#  u'obedient': 20523,
#  u'beloved': 5634,
#  u'hap': 14760,
#  u'hat': 14851,
#  u'weeklies': 31236,
#  u'lubed': 18323,
#  u'elevation': 11546,
#  u'municipal': 19864,
#  u'confidentially': 8400,
#  u'0667': 201,
#  u'elders': 11498,
#  u'survival': 28262,
#  u'mispronounced': 19408,
#  u'unequivocally': 30073,
#  u'wavelength': 31167,
#  u'indicative': 16079,
#  u'ratcheting': 23677,
#  u'distortion': 10812,
#  u'shadow': 26135,
#  u'summons': 28125,
#  u'desire': 10150,
#  u'masonic': 18768,
#  u'semi': 25955,
#  u'burnaby': 6615,
#  u'alice': 4022,
#  u'niels': 20263,
#  u'crematorium': 9153,
#  u'cogs': 7888,
#  u'baskets': 5439,
#  u'experimentally': 12424,
#  u'follows': 13305,
#  u'withheld': 31526,
#  u'687955': 2529,
#  u'sebastian': 25852,
#  u'carting': 7005,
#  u'gads': 13763,
#  u'vats': 30625,
#  u'warping': 31107,
#  u'beneficial': 5656,
#  u'sordid': 27034,
#  u'creek': 9147,
#  u'crowd': 9244,
#  u'czech': 9466,
#  u'mosques': 19701,
#  u'crown': 9250,
#  u'begin': 5576,
#  u'deflection': 9846,
#  u'crows': 9253,
#  u'nemesis': 20148,
#  u'emphases': 11671,
#  u'055': 177,
#  u'fiduciary': 12942,
#  u'harassment': 14777,
#  u'neutrino': 20189,
#  u'creep': 9149,
#  u'enemies': 11791,
#  u'anne': 4334,
#  u'26601': 1438,
#  u'cocaine': 7848,
#  u'304': 1555,
#  u'iniquities': 16278,
#  u'univ': 30177,
#  u'inhuman': 16274,
#  u'subclass': 27927,
#  u'polluted': 22351,
#  u'contributing': 8715,
#  u'disheartened': 10642,
#  u'exposition': 12479,
#  u'052': 171,
#  u'locksmithing': 18172,
#  u'00000074': 6,
#  u'theological': 28868,
#  u'howell': 15466,
#  u'palatable': 21293,
#  u'shaker': 26148,
#  u'shakes': 26149,
#  u'binded': 5790,
#  u'stefan': 27593,
#  u'stances': 27468,
#  u'eduard': 11416,
#  u'74108': 2673,
#  u'binder': 5791,
#  u'substituted': 28011,
#  u'yoke': 31810,
#  u'defensive': 9817,
#  u'anagram': 4235,
#  u'pliers': 22236,
#  u'caskets': 7034,
#  u'marital': 18691,
#  u'shaken': 26147,
#  u'hov': 15459,
#  u'entrants': 11902,
#  u'28657': 1498,
#  u'benched': 5645,
#  u'aden': 3646,
#  u'driveway': 11147,
#  u'3511': 1702,
#  u'iguanas': 15709,
#  u'lemmings': 17809,
#  u'soc': 26909,
#  u'handedness': 14714,
#  u'sod': 26936,
#  u'facility': 12595,
#  u'infraction': 16237,
#  u'marshall': 18731,
#  u'honeymoon': 15335,
#  u'rotations': 25199,
#  u'mba': 18878,
#  u'son': 27010,
#  u'administer': 3676,
#  u'undermining': 30000,
#  u'beings': 5601,
#  u'daffy': 9479,
#  u'raiser': 23593,
#  u'furnishing': 13729,
#  u'sow': 27089,
#  u'wrap': 31658,
#  u'shoots': 26306,
#  u'despised': 10169,
#  u'fabric': 12575,
#  u'abstractions': 3420,
#  u'suffice': 28077,
#  u'constantly': 8572,
#  u'13676': 679,
#  u'nova': 20442,
#  u'raped': 23654,
#  u'waite': 31024,
#  u'grasping': 14365,
#  u'authorized': 5062,
#  u'greatness': 14394,
#  u'rapes': 23655,
#  u'bloomington': 5983,
#  u'trappings': 29465,
#  u'launching': 17641,
#  u'bedrock': 5545,
#  u'magnificent': 18465,
#  u'thesaurus': 28903,
#  u'1846': 998,
#  u'forsaking': 13447,
#  u'safeguard': 25408,
#  u'4600': 1971,
#  u'verdi': 30700,
#  u'powder': 22524,
#  u'underdeveloped': 29973,
#  u'congratulations': 8455,
#  u'humbled': 15521,
#  u'toolkits': 29205,
#  u'genealogy': 13923,
#  u'masquerading': 18772,
#  u'arrays': 4718,
#  u'inside': 16374,
#  u'devices': 10273,
#  u'smashes': 26800,
#  u'humbles': 15522,
#  u'complications': 8203,
#  u'smashed': 26798,
#  u'dues': 11212,
#  u'accelerate': 3449,
#  u'151': 797,
#  u'passenger': 21496,
#  u'153': 812,
#  u'bedouin': 5543,
#  u'disgrace': 10631,
#  u'154': 820,
#  u'157': 837,
#  u'156': 831,
#  u'megahertz': 18990,
#  u'crucifixions': 9264,
#  u'disclosing': 10569,
#  u'textbook': 28828,
#  u'fanzine': 12712,
#  u'inerrant': 16145,
#  u'timezone': 29090,
#  u'correlation': 8902,
#  u'triangles': 29532,
#  u'0845': 243,
#  u'snappier': 26851,
#  u'relay': 24267,
#  u'eventual': 12204,
#  u'glacier': 14084,
#  u'cambodia': 6802,
#  u'detracts': 10241,
#  u'pasadena': 21486,
#  u'role': 25128,
#  u'brent': 6339,
#  u'benefiting': 5658,
#  u'sunset': 28143,
#  u'kinks': 17369,
#  u'roll': 25130,
#  u'emended': 11636,
#  u'cabrera': 6717,
#  u'intend': 16499,
#  u'palms': 21308,
#  u'pronounced': 23037,
#  u'models': 19507,
#  u'uncreate': 29952,
#  u'ointment': 20705,
#  u'taurus': 28600,
#  u'cleaved': 7693,
#  u'7944': 2794,
#  u'mahdi': 18474,
#  u'devon': 10284,
#  u'intent': 16511,
#  u'miranda': 19349,
#  u'variable': 30598,
#  u'transporter': 29454,
#  u'entrust': 11910,
#  u'explosions': 12464,
#  u'99': 3304,
#  u'shootout': 26305,
#  u'domingo': 10958,
#  u'highness': 15147,
#  u'rockers': 25099,
#  u'glass': 14099,
#  u'80386': 2821,
#  u'80387': 2822,
#  u'contacts': 8627,
#  u'schismatics': 25666,
#  u'ordination': 20895,
#  u'defamation': 9789,
#  u'6956': 2551,
#  u'volkswagens': 30936,
#  u'inverness': 16724,
#  u'conferred': 8386,
#  u'overturned': 21186,
#  u'treatises': 29503,
#  u'subvert': 28038,
#  u'rasters': 23674,
#  u'cincinnati': 7543,
#  u'chaim': 7220,
#  u'chain': 7221,
#  u'technologies': 28648,
#  u'activated': 3579,
#  u'umbrage': 29834,
#  ...}

# %%
print(tfidf_test[0])
# Out:
#   (0, 14792)	0.41697719982013937
#   (0, 11529)	0.5181514765439229
#   (0, 8265)	0.5167295502086905
#   (0, 8214)	0.5391100389777885

# %%
vectorizer.get_feature_names()[8214]
# Out:
# u'components'

# %%
vectorizer.get_feature_names()[8265]
# Out:
# u'computers'

# %%
vectorizer.get_feature_names()[11529]
# Out:
# u'electronic'

# %%
distances, inds_pred = predictor.kneighbors(tfidf_test, n_neighbors=10)

# %%
distances = np.squeeze(distances)
inds_pred = np.squeeze(inds_pred)

# %%
plt.figure(figsize=(15, 5))

plt.plot(distances)
plt.grid(True)
plt.ylim(0, 1)
# Out:
# (0, 1)

# %%
for i, item in enumerate(np.asarray(ng_train.data)[valid_inds[inds_pred]], start=1):
    print '--------------------------- Top-{} ---------------------------'.format(i)
    print item
    print '---------------------------- end -----------------------------'
    print
# Out:
# --------------------------- Top-1 ---------------------------
#
#  Computers are a special case.. and it's a pretty good idea to
#  leave them on.. cuz everytime you turn on a computer, you're
#  putting a surge of electricity through its delicate components.
#   Imagine you're turning on your computer 5 or more times a day.
#  You're increasing the chances of damaging the chips, memory,
#  etc on all the components of your computer. So you may save
#  a few cents here and there in electricity bills, but it won't
#  look like much when it come time to fix your computer.
# ---------------------------- end -----------------------------
#
# --------------------------- Top-2 ---------------------------
#
# Good point...also, I wouldn't be surprised that the components
# they use off-shore are of inferior quality.  As long as it was
# properly designed and robust, premium components are used, it
# shouldn't matter where it is assembled.
#
#
# An amp that runs hot has no bearing on how it's gonna sound.
# The amp you have probably is running Class-A the whole day.
#
# Actually, I'd be wary of excessively hot amps, 'cauz even though
# the components inside may be rated to run that way, excessive
# heat will dramatically shorten the life of *any* electronic component
# regardless of quality.  In fact, an amp that does run hot to the touch is
# because either the engineer or manufacturer of that amp wanted
# to skimp on heatsinking or cooling to save costs!  Hmmmmm....
#
# aaron
# ---------------------------- end -----------------------------
#
# --------------------------- Top-3 ---------------------------
# : >I was also sceptical about the amps being built in the far-east
# : >  or where-ever.  But if you look in the amp and see what components
# : >  they use and how it was designed, you can easily see why the
# : >  amplifiers sound so brilliant.
#
# : Good point...also, I wouldn't be surprised that the components
# : they use off-shore are of inferior quality.  As long as it was
# : properly designed and robust, premium components are used, it
# : shouldn't matter where it is assembled.
#
# Definately, I agree wholeheartedly.  If they can build the amp where
#   the labour is not so expensive, they can afford to put decent
#   components in and go to more effort to improve the design of the
#   amplifier - as Adcom has done.
#
# : >I cannot see why people say the amplifier won't last - not with
# : >  those quality components inside.  Sure the amp runs very fairly
# : >  hot - but that's how you get an amp to sound incredibly good.
#
# : An amp that runs hot has no bearing on how it's gonna sound.
# : The amp you have probably is running Class-A the whole day.
#
# : Actually, I'd be wary of excessively hot amps, 'cauz even though
# : the components inside may be rated to run that way, excessive
# : heat will dramatically shorten the life of *any* electronic component
# : regardless of quality.  In fact, an amp that does run hot to the touch is
# : because either the engineer or manufacturer of that amp wanted
# : to skimp on heatsinking or cooling to save costs!  Hmmmmm....
#
# Sure, I didn't mean to imply that because of the heat generated, the
#   amp sounds good.  My Adcom GFP 535II runs fairly warm - not hot to
#   the touch - but enough to satisfy me that the amp is running nicely.
# I don't like it when an amp runs dead-cold.  It makes one think that
#   the amp is doing nothing :)
# The heatsinks that Adcom uses in their amps are certainly far for
#   skimpy - they're massive things with heating vents both below
#   and above.  More than enough to carry away excessive heat.
#
# My opinions once again.
#
# ---------------------------- end -----------------------------
#
# --------------------------- Top-4 ---------------------------
#
#
# RS Components (they exist in Australia and the UK. Don't know about the US) have
# little chips called Isolated MAX 250 and 251. They give you isolated RS-232 from
# a single 5V supply. External components are 4 caps, 4 optoisolators, a diode,
# and an isloting transformer. They go up to 19.2K baud..
#
# John West
# ---------------------------- end -----------------------------
#
# --------------------------- Top-5 ---------------------------
# Hey all:
#
# I just moved to NYC and wondered if there are any electronics hackers
# out there who could point me to places in NYC that sell individual
# electronic components (switches, pots, transformers, caps,
# transistors, etc.)  "Radio Shack" doesn't count (they have almost no
# selection, and their prices are outrageous!)
#
# I have particular interest in audio components (amplifier IC's, power
# MOSFETS, output transformers, tubes and tube sockets, pan pots,
# faders, etc.)
#
# I have checked out a lot of 48th street and Canal street so far with
# no luck.  Am I missing places, looking in the wrong place, or do I
# have to resort to mail order?
# ---------------------------- end -----------------------------
#
# --------------------------- Top-6 ---------------------------
#
#
# We have plenty of computer labs where the computers are left on all the
# time. I don't see any shorter lifespan than the ones we have in the
# offices which does get turned off at the end of the day. In fact, some
# of the computers in the labs have outlived some of the same ones in the
# offices. But it goes both ways so can't conclude anything.
# ---------------------------- end -----------------------------
#
# --------------------------- Top-7 ---------------------------
# What is hardware handshaking and when do I want to use it? Dan
#
#
# ---------------------------- end -----------------------------
#
# --------------------------- Top-8 ---------------------------
# If anyone has any information about the upcoming new computers
# (Cyclone and Tempest), I am in need of some info. Anything would be
# greatly appreciated.
#
# Thanks,
# ---------------------------- end -----------------------------
#
# --------------------------- Top-9 ---------------------------
#
#
# I have (had) several problems with the card.
# - Applications crashed when moving the mouse (VGA mode). Fixed by removing
#   the line STACKS=0,0 from config.sys. The default value STACKS=9,256
#   does just fine.
# - Random white pixels all over the screen when moving the mouse, in a
#   256 color graphical mode (the hardware cursor modes). Fixed by turning
#   off the hardware scroll ("24xmode scrolloff") before entering the graphics
#   mode. This also fixed the problem of the windowed DOS boxes under windows.
#   With the hardware scroll enabled, applications write garbage outside the
#   window.
# - The screensavers do not remove the cursor in 256 color modes (hardware
#   cursor). I don't know if this is a windows problem or a driver problem.
#   Clearly there should be two types of cursor removing functions: a remove-
#   for-draw, which can be ignored for hardware cursors and a remove-
#   unconditionally. Do other cards with hardware cursors have the same problem?
# - The VESA driver does not support the 640x480x16M TrueColor mode. (Universal
#   VESA drivers do not run at all).
#
# ---------------------------- end -----------------------------
#
# --------------------------- Top-10 ---------------------------
#
#
# AT the MICRO$OFT display at FOSE, there were a few computers running
# windows, and win. apps for the  blind, I think.  Didn't pay much
# attention to it, but it was there.
#
# Mickey
# ---------------------------- end -----------------------------
